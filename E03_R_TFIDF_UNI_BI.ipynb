# %% [markdown]
# # Creacion del ResourceArn

# %%
import shutil, os

os.makedirs("provenance", exist_ok=True)
shutil.copy("/opt/ml/metadata/resource-metadata.json", "provenance/sagemaker-resource-metadata.json")

# Verifica que se copió bien y revisa el ResourceArn
import json
with open("provenance/sagemaker-resource-metadata.json") as f:
    meta = json.load(f)
print(meta.get("ResourceArn"))
# Out:
# arn:aws:sagemaker:us-east-1:587058027292:notebook-instance/AnalisisDeSentimientos

# %% [markdown]
# # Instalacion

# %%
# !pip install datasets mlflow scikit-learn -q

# %%
# %pip install -q datasets mlflow==3.16.0 scikit-learn pandas numpy emoji spacy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importacion del dataset

# %%
from datasets import load_dataset

dataset = load_dataset(
    "adilbekovich/Sentiment140Twitter",
    revision="b6037e127257d95b9b23d31f78b264b9ebe697fd"
)

train = dataset["train"]
test = dataset["test"]

print(train.num_rows, test.num_rows)  # debería imprimir 1360000 240000
# Out:
# 1360000 240000

# %% [markdown]
# # Se convierte a pandas y conserva el indice original

# %%
import pandas as pd

train_df = train.to_pandas()
train_df["index"] = train_df.index  # conserva la posición original ANTES de muestrear

print(train_df.shape)
print(train_df.columns.tolist())
# Out:
# (1360000, 3)
# ['text', 'label', 'index']

# %%
import pandas as pd

protocol_run_id = "5159d4c11e934382ad32d19269f79112"

partitions = pd.read_csv("protocol/partitions.csv")

print("Train:", train_df.shape)
print("Partitions:", partitions.shape)
print(partitions["fold"].value_counts().sort_index())

assert len(partitions) == 200000
assert partitions["index"].is_unique
assert set(partitions["fold"]) == {0, 1, 2}

print("OK - protocolo oficial cargado")
# Out:
# Train: (1360000, 3)
# Partitions: (200000, 2)
# fold
# 0    66667
# 1    66667
# 2    66666
# Name: count, dtype: int64
# OK - protocolo oficial cargado

# %%
import numpy as np
import json
import sklearn
from sklearn.metrics import f1_score

# %%
protocol_run_id = "5159d4c11e934382ad32d19269f79112"

# %% [markdown]
# # Muestra estratificada de 200.000, semilla 42

# %%
from sklearn.model_selection import train_test_split

# Ajusta "label" al nombre real de tu columna de etiqueta
sample_df, _ = train_test_split(
    train_df,
    train_size=200000,
    stratify=train_df["label"],
    random_state=42
)

sample_df = sample_df.reset_index(drop=True)  # el índice original ya quedó guardado en la columna "index"
print(sample_df.shape)
print(sample_df["label"].value_counts())
# Out:
# (200000, 3)
# label
# 1    100019
# 0     99981
# Name: count, dtype: int64

# %% [markdown]
# # Construir los 3 folds estratificados

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np

skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

sample_df["fold"] = -1
for fold_num, (_, val_idx) in enumerate(skf.split(sample_df, sample_df["label"])):
    sample_df.loc[val_idx, "fold"] = fold_num

print(sample_df["fold"].value_counts())
# Out:
# fold
# 1    66667
# 0    66667
# 2    66666
# Name: count, dtype: int64

# %% [markdown]
# # Generar protocol/partitions.csv

# %%
partitions = sample_df[["index", "fold"]].sort_values("index").reset_index(drop=True)

os.makedirs("protocol", exist_ok=True)
partitions.to_csv("protocol/partitions.csv", index=False)

print(partitions.shape)  # debe ser (200000, 2)
partitions.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 partitions = sample_df[["index", "fold"]].sort_values("index").reset_index(drop=True)
#       3 os.makedirs("protocol", exist_ok=True)
#       4 partitions.to_csv("protocol/partitions.csv", index=False)
#
# NameError: name 'sample_df' is not defined

# %% [markdown]
# # Generar protocol/members.csv

# %%
members = pd.DataFrame([
    {"member_id": "E01", "notebook_arn": "arn:aws:sagemaker:us-east-1:492606007513:notebook-instance/analisis-sentimientos"},
    {"member_id": "E02", "notebook_arn": "arn:aws:sagemaker:us-east-1:214844251412:notebook-instance/analisis-de-sentimientos"},
    {"member_id": "E03", "notebook_arn": "arn:aws:sagemaker:us-east-1:587058027292:notebook-instance/AnalisisDeSentimientos"}
])

members = members.sort_values("member_id").reset_index(drop=True)
members.to_csv("protocol/members.csv", index=False)
members
# Out:
#   member_id                                       notebook_arn
# 0       E01  arn:aws:sagemaker:us-east-1:492606007513:noteb...
# 1       E02  arn:aws:sagemaker:us-east-1:214844251412:noteb...
# 2       E03  arn:aws:sagemaker:us-east-1:587058027292:noteb...

# %%
train_df.columns.tolist()
# Out:
# ['text', 'label', 'index']

# %%
train_df.head()
# Out:
#                                                 text  label  index
# 0  Closet organizer install complete.  Now for th...      0      0
# 1  Mornin' All!!  ....I need to wake up....this w...      1      1
# 2  @Lega_c ahhhhhhhhhh! he suxxxxxxx! he claimed ...      0      2
# 3  @endlessblush Haha. I guess all the good bits ...      0      3
# 4                                  family guy funny       1      4

# %%
print(partitions.shape)
print(sample_df["label"].value_counts())
print(sample_df["fold"].value_counts())
# Out:
# (200000, 2)
# label
# 1    100019
# 0     99981
# Name: count, dtype: int64
# fold
# 1    66667
# 0    66667
# 2    66666
# Name: count, dtype: int64

# %% [markdown]
# ## Conectarse al mlflow

# %%
# !pip install mlflow -q

# %%
import mlflow

mlflow.set_tracking_uri("http://ec2-100-26-91-142.compute-1.amazonaws.com:5000")
mlflow.set_experiment("nlp-lab2-sentiment140")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1789655162210, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1789655162210, lifecycle_stage='active', name='nlp-lab2-sentiment140', tags={}, trace_location=None, workspace='default'>

# %% [markdown]
# ## Run de registro

# %%
with mlflow.start_run(run_name="protocol") as run:
    mlflow.set_tag("lab_run_type", "protocol")

    mlflow.log_param("dataset_id", "adilbekovich/Sentiment140Twitter")
    mlflow.log_param("dataset_revision", "b6037e127257d95b9b23d31f78b264b9ebe697fd")
    mlflow.log_param("sampling_strategy", "stratified")
    mlflow.log_param("sample_size", 200000)
    mlflow.log_param("random_seed", 42)
    mlflow.log_param("cv_strategy", "StratifiedKFold")
    mlflow.log_param("cv_folds", 3)
    mlflow.log_param("cv_shuffle", True)

    mlflow.log_artifact("protocol/partitions.csv", artifact_path="protocol")
    mlflow.log_artifact("protocol/members.csv", artifact_path="protocol")

    protocol_run_id = run.info.run_id
    print("Protocol run ID:", protocol_run_id)
# Out:
# Protocol run ID: 5159d4c11e934382ad32d19269f79112
# 🏃 View run protocol at: http://ec2-54-160-133-217.compute-1.amazonaws.com:5000/#/experiments/1/runs/5159d4c11e934382ad32d19269f79112
# 🧪 View experiment at: http://ec2-54-160-133-217.compute-1.amazonaws.com:5000/#/experiments/1

# %% [markdown]
# Registra el dataset, muestra folds e integrantes, todavia no se entrena nada

# %%
import numpy as np
import json
import sklearn
from sklearn.metrics import f1_score

# %% [markdown]
# ## Funcion generica de evaluacion

# %%
# !pip install scikit-learn mlflow datasets -q

# %%
def evaluate_pipeline(build_pipeline_fn, train_df, partitions_df):
    # Solo nos quedamos con las columnas necesarias de train_df, sin la columna 'fold' propia
    base = train_df[["index", "text", "label"]]
    merged = base.merge(partitions_df, on="index", how="inner")
    assert len(merged) == len(partitions_df), "La muestra no coincide con partitions.csv"

    fold_scores = []
    for fold_k in sorted(merged["fold"].unique()):
        train_part = merged[merged["fold"] != fold_k]
        val_part = merged[merged["fold"] == fold_k]

        X_train, y_train = train_part["text"].tolist(), train_part["label"].values
        X_val, y_val = val_part["text"].tolist(), val_part["label"].values

        model = build_pipeline_fn(X_train, y_train)
        y_pred = model.predict(X_val)

        f1 = f1_score(y_val, y_pred, average="macro")
        fold_scores.append(f1)
        print(f"  Fold {fold_k}: Macro-F1 = {f1:.4f}")

    mean_f1 = np.mean(fold_scores)
    std_f1 = np.std(fold_scores, ddof=0)
    return fold_scores, mean_f1, std_f1

# %% [markdown]
# ## TO - clase mas frecuente

# %%
class MostFrequentClassifier:
    def __init__(self):
        self.majority_class = None

    def fit(self, X, y):
        counts = pd.Series(y).value_counts()
        if len(counts) > 1 and counts.iloc[0] == counts.iloc[1]:
            self.majority_class = 0  # empate -> negative
        else:
            self.majority_class = counts.idxmax()
        return self

    def predict(self, X):
        return np.full(len(X), self.majority_class)


def build_t0(X_train, y_train):
    model = MostFrequentClassifier()
    model.fit(X_train, y_train)
    return model

print("Evaluando T0...")
t0_scores, t0_mean, t0_std = evaluate_pipeline(build_t0, sample_df, partitions)
print(f"T0 -> mean={t0_mean:.4f}, std={t0_std:.4f}")
# Out:
# Evaluando T0...
#   Fold 0: Macro-F1 = 0.3334
#   Fold 1: Macro-F1 = 0.3334
#   Fold 2: Macro-F1 = 0.3334
# T0 -> mean=0.3334, std=0.0000

# %% [markdown]
# ## Registrar TO en MLflow

# %%
client = mlflow.tracking.MlflowClient()
exp = client.get_experiment_by_name("nlp-lab2-sentiment140")
runs = client.search_runs(exp.experiment_id, filter_string="tags.lab_run_type = 'protocol'")
protocol_run_id = runs[0].info.run_id
print("Protocol run ID recuperado:", protocol_run_id)
# Out:
# Protocol run ID recuperado: 5159d4c11e934382ad32d19269f79112

# %%
import json

t0_config = {
    "preprocessing": None,
    "representation": None,
    "classifier": {
        "type": "most_frequent",
        "library": "custom",
        "library_version": "1.0",
        "parameters": {}
    }
}

with mlflow.start_run(run_name="T0") as run:
    mlflow.set_tag("lab_run_type", "experiment")
    mlflow.set_tag("lab_protocol_run_id", protocol_run_id)
    mlflow.set_tag("lab_experiment_id", "T0")
    mlflow.set_tag("lab_stage", "reference")
    mlflow.set_tag("lab_member_id", "E01")  # ajusta a tu member_id real
    mlflow.set_tag("lab_configuration_id", "CFG_T0")
    mlflow.set_tag("notebook_arn", meta.get("ResourceArn"))

    for i, f1 in enumerate(t0_scores):
        mlflow.log_metric(f"macro_f1_fold_{i}", f1)
    mlflow.log_metric("macro_f1_mean", t0_mean)
    mlflow.log_metric("macro_f1_std", t0_std)

    with open("configuration.json", "w") as f:
        json.dump(t0_config, f, indent=2)
    mlflow.log_artifact("configuration.json", artifact_path="run")

    mlflow.log_artifact("provenance/sagemaker-resource-metadata.json", artifact_path="provenance")

    t0_run_id = run.info.run_id
    print("T0 run ID:", t0_run_id)
# Out:
# T0 run ID: fb9bee918f744b2bb15645d411fdf6b0
# 🏃 View run T0 at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1/runs/fb9bee918f744b2bb15645d411fdf6b0
# 🧪 View experiment at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1

# %% [markdown]
# ## BO-BoW + regresion logistica

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
import re

def preprocess_b0(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "url", text)
    text = re.sub(r"@\w+", "user", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

def build_b0(X_train, y_train):
    X_train_proc = [preprocess_b0(t) for t in X_train]
    pipeline = Pipeline([
        ("vectorizer", CountVectorizer(ngram_range=(1, 1))),
        ("clf", LogisticRegression())
    ])
    pipeline.fit(X_train_proc, y_train)

    class Wrapped:
        def predict(self, X):
            X_proc = [preprocess_b0(t) for t in X]
            return pipeline.predict(X_proc)
    return Wrapped()

print("Evaluando B0...")
b0_scores, b0_mean, b0_std = evaluate_pipeline(build_b0, sample_df, partitions)
print(f"B0 -> mean={b0_mean:.4f}, std={b0_std:.4f}")
# Out:
# Evaluando B0...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 0: Macro-F1 = 0.7817
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 1: Macro-F1 = 0.7836
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 2: Macro-F1 = 0.7819
# B0 -> mean=0.7824, std=0.0009

# %% [markdown]
# ## Registrar BO en MLflow

# %%
import sklearn

b0_config = {
    "preprocessing": {
        "lowercase": True,
        "url": "token:url",
        "mention": "token:user",
        "whitespace": "normalize",
        "stopwords": "keep",
        "negators": [],
        "lemmatize": False,
        "elongation": "keep",
        "elongation_spec": None,
        "emoji": "keep",
        "emoji_spec": None,
        "resources": {},
        "additional": {}
    },
    "representation": {
        "type": "bow",
        "ngram_range": [1, 1],
        "library": "sklearn",
        "library_version": sklearn.__version__,
        "spacy_model": None,
        "spacy_model_version": None,
        "parameters": {}
    },
    "classifier": {
        "type": "logistic_regression",
        "library": "sklearn",
        "library_version": sklearn.__version__,
        "parameters": {}
    }
}

with mlflow.start_run(run_name="B0") as run:
    mlflow.set_tag("lab_run_type", "experiment")
    mlflow.set_tag("lab_protocol_run_id", protocol_run_id)
    mlflow.set_tag("lab_experiment_id", "B0")
    mlflow.set_tag("lab_stage", "baseline")
    mlflow.set_tag("lab_member_id", "E01")
    mlflow.set_tag("lab_configuration_id", "CFG_B0")
    mlflow.set_tag("notebook_arn", meta.get("ResourceArn"))

    for i, f1 in enumerate(b0_scores):
        mlflow.log_metric(f"macro_f1_fold_{i}", f1)
    mlflow.log_metric("macro_f1_mean", b0_mean)
    mlflow.log_metric("macro_f1_std", b0_std)

    with open("configuration.json", "w") as f:
        json.dump(b0_config, f, indent=2)
    mlflow.log_artifact("configuration.json", artifact_path="run")

    mlflow.log_artifact("provenance/sagemaker-resource-metadata.json", artifact_path="provenance")

    b0_run_id = run.info.run_id
    print("B0 run ID:", b0_run_id)
# Out:
# B0 run ID: 11b95d08b9af461aaf0e29fba3c6fdba
# 🏃 View run B0 at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1/runs/11b95d08b9af461aaf0e29fba3c6fdba
# 🧪 View experiment at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1

# %% [markdown]
# ## Instalar spacy

# %%
# !pip install spacy -q
# !python -m spacy download en_core_web_sm -q
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## Carga de spacy y definir los navegadores del equipo

# %%
import spacy
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

# Negadores que el equipo decide preservar aunque se eliminen stopwords
NEGATORS = ["not", "no", "never", "n't", "none", "nobody", "nothing", "neither", "nor"]

# %% [markdown]
# ## Funcion de preprocesamiento

# %%
import re

def preprocess_text(text, stopwords_mode="keep", lemmatize=False,
                     elongation="keep", emoji_mode="keep"):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "url", text)
    text = re.sub(r"@\w+", "user", text)

    if elongation == "normalize":
        # reduce repeticiones de 3+ caracteres a 2 (ej: "soooo" -> "soo")
        text = re.sub(r"(.)\1{2,}", r"\1\1", text)

    if emoji_mode == "text":
        import emoji as emoji_lib
        text = emoji_lib.demojize(text, delimiters=(" ", " "))

    text = re.sub(r"\s+", " ", text).strip()

    if stopwords_mode == "keep" and not lemmatize:
        return text

    doc = nlp(text)
    tokens = []
    for token in doc:
        word = token.text
        is_stop = token.is_stop or word in NEGATORS  # spaCy no siempre marca "n't" como stop

        if stopwords_mode == "remove" and is_stop:
            continue
        if stopwords_mode == "remove_preserve_negation" and is_stop and word not in NEGATORS:
            continue

        if lemmatize:
            word = token.lemma_

        tokens.append(word)

    return " ".join(tokens)

# %%
# !pip install emoji -q

# %% [markdown]
# ## Funcion para construir y evaluar pipeline BoW+LogReg con procesamiento

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

def make_build_fn(preprocess_kwargs):
    def build_fn(X_train, y_train):
        X_train_proc = [preprocess_text(t, **preprocess_kwargs) for t in X_train]
        pipeline = Pipeline([
            ("vectorizer", CountVectorizer(ngram_range=(1, 1))),
            ("clf", LogisticRegression())
        ])
        pipeline.fit(X_train_proc, y_train)

        class Wrapped:
            def predict(self, X):
                X_proc = [preprocess_text(t, **preprocess_kwargs) for t in X]
                return pipeline.predict(X_proc)
        return Wrapped()
    return build_fn

# %% [markdown]
# ## Funcion generica de registro en Mlflow

# %%
def log_experiment_run(run_name, lab_experiment_id, lab_stage, configuration_id,
                        config_json, scores, mean_f1, std_f1, member_id="E01"):
    with mlflow.start_run(run_name=run_name) as run:
        mlflow.set_tag("lab_run_type", "experiment")
        mlflow.set_tag("lab_protocol_run_id", protocol_run_id)
        mlflow.set_tag("lab_experiment_id", lab_experiment_id)
        mlflow.set_tag("lab_stage", lab_stage)
        mlflow.set_tag("lab_member_id", member_id)
        mlflow.set_tag("lab_configuration_id", configuration_id)
        mlflow.set_tag("notebook_arn", meta.get("ResourceArn"))

        for i, f1 in enumerate(scores):
            mlflow.log_metric(f"macro_f1_fold_{i}", f1)
        mlflow.log_metric("macro_f1_mean", mean_f1)
        mlflow.log_metric("macro_f1_std", std_f1)

        with open("configuration.json", "w") as f:
            json.dump(config_json, f, indent=2)
        mlflow.log_artifact("configuration.json", artifact_path="run")

        mlflow.log_artifact("provenance/sagemaker-resource-metadata.json", artifact_path="provenance")

        print(f"{lab_experiment_id} run ID:", run.info.run_id)
        return run.info.run_id

# %% [markdown]
# ## Base de configuracion

# %%
import copy

def base_config():
    return {
        "preprocessing": {
            "lowercase": True, "url": "token:url", "mention": "token:user",
            "whitespace": "normalize", "stopwords": "keep", "negators": [],
            "lemmatize": False, "elongation": "keep", "elongation_spec": None,
            "emoji": "keep", "emoji_spec": None, "resources": {}, "additional": {}
        },
        "representation": {
            "type": "bow", "ngram_range": [1, 1], "library": "sklearn",
            "library_version": sklearn.__version__, "spacy_model": None,
            "spacy_model_version": None, "parameters": {}
        },
        "classifier": {
            "type": "logistic_regression", "library": "sklearn",
            "library_version": sklearn.__version__, "parameters": {}
        }
    }

# %% [markdown]
# ## P_STOPWORDS

# %%
config = base_config()
config["preprocessing"]["stopwords"] = "remove"

build_fn = make_build_fn({"stopwords_mode": "remove"})
print("Evaluando P_STOPWORDS...")
scores, mean_f1, std_f1 = evaluate_pipeline(build_fn, sample_df, partitions)
print(f"P_STOPWORDS -> mean={mean_f1:.4f}, std={std_f1:.4f}")

log_experiment_run("P_STOPWORDS", "P_STOPWORDS", "preprocessing", "CFG_P_STOPWORDS",
                    config, scores, mean_f1, std_f1)
# Out:
# Evaluando P_STOPWORDS...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 0: Macro-F1 = 0.7579
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 1: Macro-F1 = 0.7608
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 2: Macro-F1 = 0.7571
# P_STOPWORDS -> mean=0.7586, std=0.0016
# P_STOPWORDS run ID: 8f4cc24b5ae74bd5a654174b6e1620b2
# 🏃 View run P_STOPWORDS at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1/runs/8f4cc24b5ae74bd5a654174b6e1620b2
# 🧪 View experiment at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1
# '8f4cc24b5ae74bd5a654174b6e1620b2'

# %%
from importlib.metadata import version

# Partimos exactamente de la configuración B0
config = base_config()

# ÚNICO cambio experimental: convertir emojis/emoticonos a texto
config["preprocessing"]["emoji"] = "text"
config["preprocessing"]["emoji_spec"] = "emoji.demojize"

# Registrar el recurso realmente utilizado
config["preprocessing"]["resources"] = {
    "emoji_library": "emoji",
    "emoji_version": version("emoji")
}

# Pipeline: BoW unigramas + Logistic Regression, igual que B0
build_fn = make_build_fn({
    "emoji_mode": "text"
})

print("====================================")
print("E03 - P_EMOJI")
print("Protocol run:", protocol_run_id)
print("Notebook ARN:", meta["ResourceArn"])
print("====================================")

# Evaluación con LOS MISMOS 3 FOLDS oficiales
scores, mean_f1, std_f1 = evaluate_pipeline(
    build_fn,
    train_df,
    partitions
)

print("\nResultados:")
for i, score in enumerate(scores):
    print(f"Fold {i}: {score:.6f}")

print(f"Macro-F1 mean: {mean_f1:.6f}")
print(f"Macro-F1 std:  {std_f1:.6f}")

# Registrar el run en el MLflow compartido
pemoji_run_id = log_experiment_run(
    run_name="P_EMOJI",
    lab_experiment_id="P_EMOJI",
    lab_stage="preprocessing",
    configuration_id="CFG_P_EMOJI",
    config_json=config,
    scores=scores,
    mean_f1=mean_f1,
    std_f1=std_f1,
    member_id="E03"
)

print("\nP_EMOJI registrado correctamente.")
print("Run ID:", pemoji_run_id)
# Out:
# ====================================
# E03 - P_EMOJI
# Protocol run: 5159d4c11e934382ad32d19269f79112
# Notebook ARN: arn:aws:sagemaker:us-east-1:587058027292:notebook-instance/AnalisisDeSentimientos
# ====================================
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 0: Macro-F1 = 0.7820
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 1: Macro-F1 = 0.7832
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Fold 2: Macro-F1 = 0.7826
#
# Resultados:
# Fold 0: 0.782024
# Fold 1: 0.783207
# Fold 2: 0.782600
# Macro-F1 mean: 0.782610
# Macro-F1 std:  0.000483
# P_EMOJI run ID: c4145efff175472794f006446946aa44
# 🏃 View run P_EMOJI at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1/runs/c4145efff175472794f006446946aa44
# 🧪 View experiment at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1
#
# P_EMOJI registrado correctamente.
# Run ID: c4145efff175472794f006446946aa44

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

def build_r_tfidf_uni_bi(X_train, y_train):
    # Preprocesamiento ganador: P_ELONGATION
    X_train_proc = [
        preprocess_text(t, elongation="normalize")
        for t in X_train
    ]

    pipeline = Pipeline([
        (
            "vectorizer",
            TfidfVectorizer(
                ngram_range=(1, 2)
            )
        ),
        (
            "clf",
            LogisticRegression()
        )
    ])

    pipeline.fit(X_train_proc, y_train)

    class Wrapped:
        def predict(self, X):
            X_proc = [
                preprocess_text(t, elongation="normalize")
                for t in X
            ]
            return pipeline.predict(X_proc)

    return Wrapped()

# %%
import sklearn

def base_config():
    return {
        "preprocessing": {
            "lowercase": True,
            "url": "token:url",
            "mention": "token:user",
            "whitespace": "normalize",
            "stopwords": "keep",
            "negators": [],
            "lemmatize": False,
            "elongation": "keep",
            "elongation_spec": None,
            "emoji": "keep",
            "emoji_spec": None,
            "resources": {},
            "additional": {}
        },
        "representation": {
            "type": "bow",
            "ngram_range": [1, 1],
            "library": "sklearn",
            "library_version": sklearn.__version__,
            "spacy_model": None,
            "spacy_model_version": None,
            "parameters": {}
        },
        "classifier": {
            "type": "logistic_regression",
            "library": "sklearn",
            "library_version": sklearn.__version__,
            "parameters": {}
        }
    }

print("base_config cargada")
# Out:
# base_config cargada

# %%
config = base_config()

# Preprocesamiento seleccionado: P_ELONGATION
config["preprocessing"]["elongation"] = "normalize"
config["preprocessing"]["elongation_spec"] = "reduce_repeated_chars_to_2"

# Representación que estamos evaluando
config["representation"]["type"] = "tfidf"
config["representation"]["ngram_range"] = [1, 2]

print(config)
# Out:
# {'preprocessing': {'lowercase': True, 'url': 'token:url', 'mention': 'token:user', 'whitespace': 'normalize', 'stopwords': 'keep', 'negators': [], 'lemmatize': False, 'elongation': 'normalize', 'elongation_spec': 'reduce_repeated_chars_to_2', 'emoji': 'keep', 'emoji_spec': None, 'resources': {}, 'additional': {}}, 'representation': {'type': 'tfidf', 'ngram_range': [1, 2], 'library': 'sklearn', 'library_version': '1.7.2', 'spacy_model': None, 'spacy_model_version': None, 'parameters': {}}, 'classifier': {'type': 'logistic_regression', 'library': 'sklearn', 'library_version': '1.7.2', 'parameters': {}}}

# %%
import numpy as np
from sklearn.metrics import f1_score

def evaluate_pipeline(build_pipeline_fn, train_df, partitions_df):
    base = train_df[["index", "text", "label"]]

    merged = base.merge(
        partitions_df,
        on="index",
        how="inner"
    )

    assert len(merged) == len(partitions_df), \
        "La muestra no coincide con partitions.csv"

    fold_scores = []

    for fold_k in sorted(merged["fold"].unique()):
        train_part = merged[merged["fold"] != fold_k]
        val_part = merged[merged["fold"] == fold_k]

        X_train = train_part["text"].tolist()
        y_train = train_part["label"].values

        X_val = val_part["text"].tolist()
        y_val = val_part["label"].values

        model = build_pipeline_fn(
            X_train,
            y_train
        )

        y_pred = model.predict(X_val)

        f1 = f1_score(
            y_val,
            y_pred,
            average="macro"
        )

        fold_scores.append(f1)

        print(
            f"Fold {fold_k}: Macro-F1 = {f1:.4f}"
        )

    mean_f1 = np.mean(fold_scores)
    std_f1 = np.std(fold_scores, ddof=0)

    return fold_scores, mean_f1, std_f1

print("evaluate_pipeline cargada")
# Out:
# evaluate_pipeline cargada

# %%
print("evaluate_pipeline:", callable(evaluate_pipeline))
print("build_r_tfidf_uni_bi:", callable(build_r_tfidf_uni_bi))
# Out:
# evaluate_pipeline: True
# build_r_tfidf_uni_bi: True

# %%
print("train_df:", train_df.shape)
print("partitions:", partitions.shape)
print("preprocess_text:", callable(preprocess_text))
print("protocol_run_id:", protocol_run_id)
print("ARN:", meta["ResourceArn"])
# Out:
# train_df: (1360000, 3)
# partitions: (200000, 2)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 print("train_df:", train_df.shape)
#       2 print("partitions:", partitions.shape)
# ----> 3 print("preprocess_text:", callable(preprocess_text))
#       4 print("protocol_run_id:", protocol_run_id)
#       5 print("ARN:", meta["ResourceArn"])
#
# NameError: name 'preprocess_text' is not defined

# %%
import re

def preprocess_text(
    text,
    stopwords_mode="keep",
    lemmatize=False,
    elongation="keep",
    emoji_mode="keep"
):
    # B0
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "url", text)
    text = re.sub(r"@\w+", "user", text)

    # P_ELONGATION
    if elongation == "normalize":
        text = re.sub(r"(.)\1{2,}", r"\1\1", text)

    # P_EMOJI
    if emoji_mode == "text":
        import emoji as emoji_lib
        text = emoji_lib.demojize(
            text,
            delimiters=(" ", " ")
        )

    text = re.sub(r"\s+", " ", text).strip()

    # Para nuestro R_TFIDF_UNI_BI no entra aquí,
    # porque mantenemos stopwords y no lematizamos
    if stopwords_mode == "keep" and not lemmatize:
        return text

    doc = nlp(text)
    tokens = []

    for token in doc:
        word = token.text
        is_stop = token.is_stop or word in NEGATORS

        if stopwords_mode == "remove" and is_stop:
            continue

        if (
            stopwords_mode == "remove_preserve_negation"
            and is_stop
            and word not in NEGATORS
        ):
            continue

        if lemmatize:
            word = token.lemma_

        tokens.append(word)

    return " ".join(tokens)

print("preprocess_text cargada")
# Out:
# preprocess_text cargada

# %%
print("train_df:", train_df.shape)
print("partitions:", partitions.shape)
print("preprocess_text:", callable(preprocess_text))
print("protocol_run_id:", protocol_run_id)
print("ARN:", meta["ResourceArn"])
# Out:
# train_df: (1360000, 3)
# partitions: (200000, 2)
# preprocess_text: True
# protocol_run_id: 5159d4c11e934382ad32d19269f79112
# ARN: arn:aws:sagemaker:us-east-1:587058027292:notebook-instance/AnalisisDeSentimientos

# %%
print("====================================")
print("E03 - R_TFIDF_UNI_BI")
print("Preprocessing: P_ELONGATION")
print("Representation: TF-IDF unigramas + bigramas")
print("Classifier: Logistic Regression")
print("====================================")

scores, mean_f1, std_f1 = evaluate_pipeline(
    build_r_tfidf_uni_bi,
    train_df,
    partitions
)

print("\nRESULTADOS")
for i, score in enumerate(scores):
    print(f"Fold {i}: {score:.6f}")

print(f"Macro-F1 mean: {mean_f1:.6f}")
print(f"Macro-F1 std:  {std_f1:.6f}")
# Out:
# ====================================
# E03 - R_TFIDF_UNI_BI
# Preprocessing: P_ELONGATION
# Representation: TF-IDF unigramas + bigramas
# Classifier: Logistic Regression
# ====================================
# Fold 0: Macro-F1 = 0.7984
# Fold 1: Macro-F1 = 0.8028
# Fold 2: Macro-F1 = 0.8004
#
# RESULTADOS
# Fold 0: 0.798395
# Fold 1: 0.802765
# Fold 2: 0.800376
# Macro-F1 mean: 0.800512
# Macro-F1 std:  0.001787

# %%
r_tfidf_uni_bi_run_id = log_experiment_run(
    run_name="R_TFIDF_UNI_BI",
    lab_experiment_id="R_TFIDF_UNI_BI",
    lab_stage="representation",
    configuration_id="CFG_R_TFIDF_UNI_BI",
    config_json=config,
    scores=scores,
    mean_f1=mean_f1,
    std_f1=std_f1,
    member_id="E03"
)

print("R_TFIDF_UNI_BI registrado correctamente")
print("Run ID:", r_tfidf_uni_bi_run_id)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 r_tfidf_uni_bi_run_id = log_experiment_run(
#       2     run_name="R_TFIDF_UNI_BI",
#       3     lab_experiment_id="R_TFIDF_UNI_BI",
#       4     lab_stage="representation",
#       5     configuration_id="CFG_R_TFIDF_UNI_BI",
#       6     config_json=config,
#       7     scores=scores,
#       8     mean_f1=mean_f1,
#       9     std_f1=std_f1,
#      10     member_id="E03"
#      11 )
#      13 print("R_TFIDF_UNI_BI registrado correctamente")
#      14 print("Run ID:", r_tfidf_uni_bi_run_id)
#
# Cell In[26], line 15, in log_experiment_run(run_name, lab_experiment_id, lab_stage, configuration_id, config_json, scores, mean_f1, std_f1, member_id)
#       4 def log_experiment_run(
#       5     run_name,
#       6     lab_experiment_id,
#    (...)
#      13     member_id
#      14 ):
# ---> 15     with mlflow.start_run(run_name=run_name) as run:
#      17         mlflow.set_tag("lab_run_type", "experiment")
#      18         mlflow.set_tag("lab_protocol_run_id", protocol_run_id)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/fluent.py:574, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     566 if len(active_run_stack) > 0 and not nested:
#     567     raise Exception(
#     568         (
#     569             "Run with UUID {} is already active. To start a new run, first end the "
#    (...)
#     572         ).format(active_run_stack[0].info.run_id)
#     573     )
# --> 574 client = MlflowClient()
#     575 sgc_job_run_id_tag_key: str | None = None
#     576 if run_id:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/client.py:254, in MlflowClient.__init__(self, tracking_uri, registry_uri, workspace_store_uri)
#     252 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#     253 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# --> 254 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#     255 self._workspace_store_uri = workspace_utils.resolve_workspace_store_uri(
#     256     workspace_store_uri, tracking_uri=final_tracking_uri
#     257 )
#     258 self._tracing_client = TracingClient(final_tracking_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:98, in TrackingServiceClient.__init__(self, tracking_uri)
#      93 self.tracking_uri = tracking_uri
#      94 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      95 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      96 # property method to ensure that the client is serializable, even if the store is not
#      97 # self.store
# ---> 98 self.store
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:102, in TrackingServiceClient.store(self)
#     100 @property
#     101 def store(self):
# --> 102     return utils._get_store(self.tracking_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:270, in _get_store(store_uri, artifact_uri)
#     269 def _get_store(store_uri=None, artifact_uri=None):
# --> 270     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/registry.py:45, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      42 from mlflow.tracking._tracking_service import utils
#      44 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 45 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/registry.py:56, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      54 with _building_store_lock:
#      55     builder = self.get_store_builder(resolved_store_uri)
# ---> 56     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:201, in _get_sqlalchemy_store(store_uri, artifact_uri)
#     196     artifact_uri = os.environ.get(
#     197         _SERVER_ARTIFACT_ROOT_ENV_VAR, DEFAULT_LOCAL_FILE_AND_ARTIFACT_PATH
#     198     )
#     200 store_cls = WorkspaceAwareSqlAlchemyStore if MLFLOW_ENABLE_WORKSPACES.get() else SqlAlchemyStore
# --> 201 return store_cls(store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py:395, in SqlAlchemyStore.__init__(self, db_uri, default_artifact_root, read_db_uri)
#     390     SessionMaker = sqlalchemy.orm.sessionmaker(bind=self.engine)
#     391     self.ManagedSessionMaker = mlflow.store.db.utils._get_managed_session_maker(
#     392         SessionMaker, self.db_type
#     393     )
# --> 395 mlflow.store.db.utils._verify_schema(self.engine)
#     396 if self.read_engine is not None:
#     397     mlflow.store.db.utils._verify_schema(self.read_engine)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/store/db/utils.py:127, in _verify_schema(engine)
#     125 current_rev = _get_schema_version(engine)
#     126 if current_rev != head_revision:
# --> 127     raise MlflowException(
#     128         f"Detected out-of-date database schema (found version {current_rev}, "
#     129         f"but expected {head_revision}). Take a backup of your database, then run "
#     130         "'mlflow db upgrade <database_uri>' "
#     131         "to migrate your database to the latest schema. NOTE: schema migration may "
#     132         "result in database downtime - please consult your database's documentation for "
#     133         "more detail."
#     134     )
#
# MlflowException: Detected out-of-date database schema (found version 6f8d9c3b2a1e, but expected b7e2c1a4d9f3). Take a backup of your database, then run 'mlflow db upgrade <database_uri>' to migrate your database to the latest schema. NOTE: schema migration may result in database downtime - please consult your database's documentation for more detail.

# %%
import json
import mlflow

def log_experiment_run(
    run_name,
    lab_experiment_id,
    lab_stage,
    configuration_id,
    config_json,
    scores,
    mean_f1,
    std_f1,
    member_id
):
    with mlflow.start_run(run_name=run_name) as run:

        mlflow.set_tag("lab_run_type", "experiment")
        mlflow.set_tag("lab_protocol_run_id", protocol_run_id)
        mlflow.set_tag("lab_experiment_id", lab_experiment_id)
        mlflow.set_tag("lab_stage", lab_stage)
        mlflow.set_tag("lab_member_id", member_id)
        mlflow.set_tag("lab_configuration_id", configuration_id)
        mlflow.set_tag("notebook_arn", meta["ResourceArn"])

        for i, f1 in enumerate(scores):
            mlflow.log_metric(f"macro_f1_fold_{i}", float(f1))

        mlflow.log_metric("macro_f1_mean", float(mean_f1))
        mlflow.log_metric("macro_f1_std", float(std_f1))

        with open("configuration.json", "w", encoding="utf-8") as f:
            json.dump(config_json, f, indent=2)

        mlflow.log_artifact(
            "configuration.json",
            artifact_path="run"
        )

        mlflow.log_artifact(
            "provenance/sagemaker-resource-metadata.json",
            artifact_path="provenance"
        )

        print("Run registrado:", run.info.run_id)

        return run.info.run_id

print("log_experiment_run cargada")
# Out:
# log_experiment_run cargada

# %%
r_tfidf_uni_bi_run_id = log_experiment_run(
    run_name="R_TFIDF_UNI_BI",
    lab_experiment_id="R_TFIDF_UNI_BI",
    lab_stage="representation",
    configuration_id="CFG_R_TFIDF_UNI_BI",
    config_json=config,
    scores=scores,
    mean_f1=mean_f1,
    std_f1=std_f1,
    member_id="E03"
)

print("R_TFIDF_UNI_BI registrado correctamente")
print("Run ID:", r_tfidf_uni_bi_run_id)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 r_tfidf_uni_bi_run_id = log_experiment_run(
#       2     run_name="R_TFIDF_UNI_BI",
#       3     lab_experiment_id="R_TFIDF_UNI_BI",
#       4     lab_stage="representation",
#       5     configuration_id="CFG_R_TFIDF_UNI_BI",
#       6     config_json=config,
#       7     scores=scores,
#       8     mean_f1=mean_f1,
#       9     std_f1=std_f1,
#      10     member_id="E03"
#      11 )
#      13 print("R_TFIDF_UNI_BI registrado correctamente")
#      14 print("Run ID:", r_tfidf_uni_bi_run_id)
#
# Cell In[26], line 15, in log_experiment_run(run_name, lab_experiment_id, lab_stage, configuration_id, config_json, scores, mean_f1, std_f1, member_id)
#       4 def log_experiment_run(
#       5     run_name,
#       6     lab_experiment_id,
#    (...)
#      13     member_id
#      14 ):
# ---> 15     with mlflow.start_run(run_name=run_name) as run:
#      17         mlflow.set_tag("lab_run_type", "experiment")
#      18         mlflow.set_tag("lab_protocol_run_id", protocol_run_id)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/fluent.py:574, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     566 if len(active_run_stack) > 0 and not nested:
#     567     raise Exception(
#     568         (
#     569             "Run with UUID {} is already active. To start a new run, first end the "
#    (...)
#     572         ).format(active_run_stack[0].info.run_id)
#     573     )
# --> 574 client = MlflowClient()
#     575 sgc_job_run_id_tag_key: str | None = None
#     576 if run_id:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/client.py:254, in MlflowClient.__init__(self, tracking_uri, registry_uri, workspace_store_uri)
#     252 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#     253 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# --> 254 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#     255 self._workspace_store_uri = workspace_utils.resolve_workspace_store_uri(
#     256     workspace_store_uri, tracking_uri=final_tracking_uri
#     257 )
#     258 self._tracing_client = TracingClient(final_tracking_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:98, in TrackingServiceClient.__init__(self, tracking_uri)
#      93 self.tracking_uri = tracking_uri
#      94 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      95 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      96 # property method to ensure that the client is serializable, even if the store is not
#      97 # self.store
# ---> 98 self.store
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:102, in TrackingServiceClient.store(self)
#     100 @property
#     101 def store(self):
# --> 102     return utils._get_store(self.tracking_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:270, in _get_store(store_uri, artifact_uri)
#     269 def _get_store(store_uri=None, artifact_uri=None):
# --> 270     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/registry.py:45, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      42 from mlflow.tracking._tracking_service import utils
#      44 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 45 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/registry.py:56, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      54 with _building_store_lock:
#      55     builder = self.get_store_builder(resolved_store_uri)
# ---> 56     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:201, in _get_sqlalchemy_store(store_uri, artifact_uri)
#     196     artifact_uri = os.environ.get(
#     197         _SERVER_ARTIFACT_ROOT_ENV_VAR, DEFAULT_LOCAL_FILE_AND_ARTIFACT_PATH
#     198     )
#     200 store_cls = WorkspaceAwareSqlAlchemyStore if MLFLOW_ENABLE_WORKSPACES.get() else SqlAlchemyStore
# --> 201 return store_cls(store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py:395, in SqlAlchemyStore.__init__(self, db_uri, default_artifact_root, read_db_uri)
#     390     SessionMaker = sqlalchemy.orm.sessionmaker(bind=self.engine)
#     391     self.ManagedSessionMaker = mlflow.store.db.utils._get_managed_session_maker(
#     392         SessionMaker, self.db_type
#     393     )
# --> 395 mlflow.store.db.utils._verify_schema(self.engine)
#     396 if self.read_engine is not None:
#     397     mlflow.store.db.utils._verify_schema(self.read_engine)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/store/db/utils.py:127, in _verify_schema(engine)
#     125 current_rev = _get_schema_version(engine)
#     126 if current_rev != head_revision:
# --> 127     raise MlflowException(
#     128         f"Detected out-of-date database schema (found version {current_rev}, "
#     129         f"but expected {head_revision}). Take a backup of your database, then run "
#     130         "'mlflow db upgrade <database_uri>' "
#     131         "to migrate your database to the latest schema. NOTE: schema migration may "
#     132         "result in database downtime - please consult your database's documentation for "
#     133         "more detail."
#     134     )
#
# MlflowException: Detected out-of-date database schema (found version 6f8d9c3b2a1e, but expected b7e2c1a4d9f3). Take a backup of your database, then run 'mlflow db upgrade <database_uri>' to migrate your database to the latest schema. NOTE: schema migration may result in database downtime - please consult your database's documentation for more detail.

# %%
import os
import mlflow

print("Tracking URI:", mlflow.get_tracking_uri())
print("MLflow experiment:", mlflow.get_experiment_by_name("nlp-lab2-sentiment140"))
print(
    "Provenance existe:",
    os.path.exists("provenance/sagemaker-resource-metadata.json")
)
# Out:
# Tracking URI: sqlite:////home/ec2-user/TallerSentimientos/mlflow.db
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[29], line 5
#       2 import mlflow
#       4 print("Tracking URI:", mlflow.get_tracking_uri())
# ----> 5 print("MLflow experiment:", mlflow.get_experiment_by_name("nlp-lab2-sentiment140"))
#       6 print(
#       7     "Provenance existe:",
#       8     os.path.exists("provenance/sagemaker-resource-metadata.json")
#       9 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/fluent.py:2198, in get_experiment_by_name(name)
#    2164 def get_experiment_by_name(name: str) -> Experiment | None:
#    2165     """
#    2166     Retrieve an experiment by experiment name from the backend store
#    2167
#    (...)
#    2196         Creation timestamp: 1662004217511
#    2197     """
# -> 2198     return MlflowClient().get_experiment_by_name(name)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/client.py:254, in MlflowClient.__init__(self, tracking_uri, registry_uri, workspace_store_uri)
#     252 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#     253 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# --> 254 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#     255 self._workspace_store_uri = workspace_utils.resolve_workspace_store_uri(
#     256     workspace_store_uri, tracking_uri=final_tracking_uri
#     257 )
#     258 self._tracing_client = TracingClient(final_tracking_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:98, in TrackingServiceClient.__init__(self, tracking_uri)
#      93 self.tracking_uri = tracking_uri
#      94 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      95 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      96 # property method to ensure that the client is serializable, even if the store is not
#      97 # self.store
# ---> 98 self.store
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:102, in TrackingServiceClient.store(self)
#     100 @property
#     101 def store(self):
# --> 102     return utils._get_store(self.tracking_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:270, in _get_store(store_uri, artifact_uri)
#     269 def _get_store(store_uri=None, artifact_uri=None):
# --> 270     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/registry.py:45, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      42 from mlflow.tracking._tracking_service import utils
#      44 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 45 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/registry.py:56, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      54 with _building_store_lock:
#      55     builder = self.get_store_builder(resolved_store_uri)
# ---> 56     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:201, in _get_sqlalchemy_store(store_uri, artifact_uri)
#     196     artifact_uri = os.environ.get(
#     197         _SERVER_ARTIFACT_ROOT_ENV_VAR, DEFAULT_LOCAL_FILE_AND_ARTIFACT_PATH
#     198     )
#     200 store_cls = WorkspaceAwareSqlAlchemyStore if MLFLOW_ENABLE_WORKSPACES.get() else SqlAlchemyStore
# --> 201 return store_cls(store_uri, artifact_uri)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py:395, in SqlAlchemyStore.__init__(self, db_uri, default_artifact_root, read_db_uri)
#     390     SessionMaker = sqlalchemy.orm.sessionmaker(bind=self.engine)
#     391     self.ManagedSessionMaker = mlflow.store.db.utils._get_managed_session_maker(
#     392         SessionMaker, self.db_type
#     393     )
# --> 395 mlflow.store.db.utils._verify_schema(self.engine)
#     396 if self.read_engine is not None:
#     397     mlflow.store.db.utils._verify_schema(self.read_engine)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/mlflow/store/db/utils.py:127, in _verify_schema(engine)
#     125 current_rev = _get_schema_version(engine)
#     126 if current_rev != head_revision:
# --> 127     raise MlflowException(
#     128         f"Detected out-of-date database schema (found version {current_rev}, "
#     129         f"but expected {head_revision}). Take a backup of your database, then run "
#     130         "'mlflow db upgrade <database_uri>' "
#     131         "to migrate your database to the latest schema. NOTE: schema migration may "
#     132         "result in database downtime - please consult your database's documentation for "
#     133         "more detail."
#     134     )
#
# MlflowException: Detected out-of-date database schema (found version 6f8d9c3b2a1e, but expected b7e2c1a4d9f3). Take a backup of your database, then run 'mlflow db upgrade <database_uri>' to migrate your database to the latest schema. NOTE: schema migration may result in database downtime - please consult your database's documentation for more detail.

# %%
import mlflow

mlflow.set_tracking_uri(
    "http://ec2-100-26-91-142.compute-1.amazonaws.com:5000"
)

mlflow.set_experiment("nlp-lab2-sentiment140")

print("Tracking URI:", mlflow.get_tracking_uri())
print(
    "Experiment:",
    mlflow.get_experiment_by_name("nlp-lab2-sentiment140").experiment_id
)
# Out:
# Tracking URI: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000
# Experiment: 1

# %%
from mlflow import MlflowClient

client = MlflowClient()

run = client.get_run(
    "5159d4c11e934382ad32d19269f79112"
)

print("Protocol encontrado:", run.info.run_id)
# Out:
# Protocol encontrado: 5159d4c11e934382ad32d19269f79112

# %%
r_tfidf_uni_bi_run_id = log_experiment_run(
    run_name="R_TFIDF_UNI_BI",
    lab_experiment_id="R_TFIDF_UNI_BI",
    lab_stage="representation",
    configuration_id="CFG_R_TFIDF_UNI_BI",
    config_json=config,
    scores=scores,
    mean_f1=mean_f1,
    std_f1=std_f1,
    member_id="E03"
)

print("R_TFIDF_UNI_BI registrado correctamente")
print("Run ID:", r_tfidf_uni_bi_run_id)
# Out:
# Run registrado: 14187e45d8f24319b9bd9ad8e40a169f
# 🏃 View run R_TFIDF_UNI_BI at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1/runs/14187e45d8f24319b9bd9ad8e40a169f
# 🧪 View experiment at: http://ec2-100-26-91-142.compute-1.amazonaws.com:5000/#/experiments/1
# R_TFIDF_UNI_BI registrado correctamente
# Run ID: 14187e45d8f24319b9bd9ad8e40a169f
